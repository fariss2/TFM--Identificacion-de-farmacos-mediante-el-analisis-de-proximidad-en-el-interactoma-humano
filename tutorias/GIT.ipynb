# %%
# !git remote set-url origin https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano.git

# %%
# !git commit -m "mejoras interfaz"
# Out:
# [main 7cb3926] mejoras interfaz
#  12 files changed, 1158 insertions(+), 77 deletions(-)
#  create mode 100644 Aplicacion/__pycache__/gene_to_uniprot.cpython-313.pyc
#  create mode 100644 Aplicacion/__pycache__/network_medicine.cpython-313.pyc
#  rename Aplicacion/{app2_v2.py => app.py} (81%)
#  create mode 100644 Aplicacion/farmacos.jpg
#  create mode 100644 Aplicacion/lib/bindings/utils.js
#  create mode 100644 Aplicacion/lib/tom-select/tom-select.complete.min.js
#  create mode 100644 Aplicacion/lib/tom-select/tom-select.css
#  create mode 100644 Aplicacion/lib/vis-9.1.2/vis-network.css
#  create mode 100644 Aplicacion/lib/vis-9.1.2/vis-network.min.js
#  create mode 100644 Aplicacion/prot.png
#  create mode 100644 Aplicacion/repo_enf.jpg

# %%
# !git push origin main
# Out:
# To https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano.git
#    a79a661..7cb3926  main -> main
