# %%
# !git remote set-url origin https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano.git

# %%
# !git add ../Aplicacion/app.py

# %%
# !git commit -m "documentaacion"
# Out:
# [main ccccaef] documentaacion
#  1 file changed, 45 insertions(+), 30 deletions(-)

# %%
# !git push origin main
# Out:
# To https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano.git
#    b8074e4..ccccaef  main -> main

# %%
# !git pull origin main
# Out:
# Merge made by the 'ort' strategy.
#  .devcontainer/devcontainer.json | 33 +++++++++++++++++++++++++++++++++
#  1 file changed, 33 insertions(+)
#  create mode 100644 .devcontainer/devcontainer.json
# From https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano
#  * branch            main       -> FETCH_HEAD
#    c99f78b..d285393  main       -> origin/main
# warning: in the working copy of 'tutorias/GIT.ipynb', LF will be replaced by CRLF the next time Git touches it

# %%
# !git stash
# Out:
# Saved working directory and index state WIP on main: e6584d3 act desde local

# %%
# !git pull origin main
# Out:
# Merge made by the 'ort' strategy.
#  Aplicacion/app.py           | 14 ++++----
#  Aplicacion/requirements.txt | 81 ++-------------------------------------------
#  2 files changed, 10 insertions(+), 85 deletions(-)
# From https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano
#  * branch            main       -> FETCH_HEAD

# %%
# !git stash pop
# Out:
# Auto-merging Aplicacion/app.py
# Auto-merging Aplicacion/requirements.txt
# CONFLICT (content): Merge conflict in Aplicacion/requirements.txt
# On branch main
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   ../Aplicacion/app.py
# 	modified:   ../Aplicacion/network_context.html
#
# Unmerged paths:
#   (use "git restore --staged <file>..." to unstage)
#   (use "git add <file>..." to mark resolution)
# 	both modified:   ../Aplicacion/requirements.txt
#
# The stash entry is kept in case you need it again.

# %%
# !git
# Out:
# warning: in the working copy of 'tutorias/GIT.ipynb', LF will be replaced by CRLF the next time Git touches it

# %%
# !git add ../Documentacion/Memoria_TFM.pdf
