# %%
# !git remote set-url origin https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano.git

# %%
# !git commit -m "directorios"
# Out:
# [main 95ba64e] directorios
#  6 files changed, 6 insertions(+), 11 deletions(-)
#  delete mode 100644 __pycache__/drug_similarity.cpython-313.pyc
#  delete mode 100644 __pycache__/drug_similarity.cpython-39.pyc
#  delete mode 100644 __pycache__/gene_to_uniprot.cpython-313.pyc
#  delete mode 100644 __pycache__/gene_to_uniprot.cpython-39.pyc
#  delete mode 100644 __pycache__/network_medicine.cpython-313.pyc

# %%
# !git push origin main
# Out:
# To https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano.git
#    ae43bc0..95ba64e  main -> main
