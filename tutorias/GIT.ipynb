# %%
# !git remote set-url origin https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano.git

# %%
# !git commit -m "directorios"
# Out:
# [main 35c8d7d] directorios
#  9 files changed, 16 insertions(+), 1036 deletions(-)
#  delete mode 100644 Memoria_TFM.pdf
#  delete mode 100644 lib/bindings/utils.js
#  delete mode 100644 lib/tom-select/tom-select.complete.min.js
#  delete mode 100644 lib/tom-select/tom-select.css
#  delete mode 100644 lib/vis-9.1.2/vis-network.css
#  delete mode 100644 lib/vis-9.1.2/vis-network.min.js

# %%
# !git push origin main
# Out:
# To https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano.git
#    cc6521e..35c8d7d  main -> main
