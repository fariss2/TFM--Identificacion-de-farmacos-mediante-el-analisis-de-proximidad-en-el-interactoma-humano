# %%
# !git remote set-url origin https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano.git

# %%
# !git add .
# !git commit -m "ficheros auxiliares"
# Out:
# warning: in the working copy of 'Untitled.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main 9a9afa7] ficheros auxiliares
#  1 file changed, 12 insertions(+), 416 deletions(-)

# %%
# !git push origin main
# Out:
# To https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano.git
#    bc30eca..9a9afa7  main -> main

# %%
import networkx as nx

# %%
nx.version()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8836\3211679037.py in <module>
# ----> 1 nx.version()
#
# AttributeError: module 'networkx' has no attribute 'version'

# %%
import networkx as nx
print(nx.__version__)
# Out:
# 3.2.1

# %%
from networkx.algorithms.link_analysis.pagerank_alg import pagerank_power
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8836\3583708538.py in <module>
# ----> 1 from networkx.algorithms.link_analysis.pagerank_alg import pagerank_power
#       2
#
# ImportError: cannot import name 'pagerank_power' from 'networkx.algorithms.link_analysis.pagerank_alg' (C:\Users\Nisrin Fariss Lamine\anaconda3\lib\site-packages\networkx\algorithms\link_analysis\pagerank_alg.py)
