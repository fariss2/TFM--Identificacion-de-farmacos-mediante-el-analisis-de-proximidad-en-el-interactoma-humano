# %%
#!pip install streamlit

# %%
#pip install --upgrade pip

# %%
# %%writefile app.py
import streamlit as st

st.title("App desde Jupyter 🚀")
st.write("Hola desde Streamlit")
# Out:
# Writing app.py

# %%
# !streamlit run app.py
# Out:
# ^C

# %%
# !git init
# !git add .
# !git commit -m "implementacion app "
# !git remote add origin https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano
# !git push -u origin main
# Out:
# Initialized empty Git repository in C:/Users/Nisrin Fariss Lamine/Downloads/tfm/.git/
# ...
# [master (root-commit) 98f7179] implementacion app
#  9 files changed, 11402 insertions(+)
#  create mode 100644 .ipynb_checkpoints/TFM-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 BIOGRID-ALL-5.0.254.tab3.txt
#  create mode 100644 TFM.ipynb
#  create mode 100644 Untitled.ipynb
#  create mode 100644 app.py
#  create mode 100644 drugbank_targets_clean.csv
#  create mode 100644 full_database.xml
#  create mode 100644 no visualizar datos.txt
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano'

# %%
# !git branch -M main
# !git push -u origin main
# Out:
# To https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano'
# hint: Updates were rejected because the remote contains work that you do not
# hint: have locally. This is usually caused by another repository pushing to
# hint: the same ref. If you want to integrate the remote changes, use
# hint: 'git pull' before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# Merge made by the 'ort' strategy.
# From https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# ...
#  README.md | 2 ++
#  1 file changed, 2 insertions(+)
#  create mode 100644 README.md

# %%
# !git push origin main
# Out:
# remote: error: Trace: aa558e4d597d9de88a35c62d77d9beddf7eea65a2a32bd393b8ce17046c37174
# remote: error: See https://gh.io/lfs for more information.
# remote: error: File BIOGRID-ALL-5.0.254.tab3.txt is 1444.54 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: File full_database.xml is 1810.17 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano
#  ! [remote rejected] main -> main (pre-receive hook declined)
# error: failed to push some refs to 'https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano'

# %%
# !git branch -M main
# !git remote add origin https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano.git
# !git pull origin main --allow-unrelated-histories
# !git push -u origin main
# Out:
# error: remote origin already exists.
# Already up to date.
# From https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano
#  * branch            main       -> FETCH_HEAD
# remote: error: Trace: 2c5c1abcfe46af1b9ec6b17d5779e926f16e9c77be1f32be74dc9108fa9ef526
# remote: error: See https://gh.io/lfs for more information.
# remote: error: File BIOGRID-ALL-5.0.254.tab3.txt is 1444.54 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: File full_database.xml is 1810.17 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano
#  ! [remote rejected] main -> main (pre-receive hook declined)
# ...

# %%
# !git rm --cached BIOGRID-ALL-5.0.254.tab3.txt
# !git rm --cached full_database.xml
# Out:
# rm 'BIOGRID-ALL-5.0.254.tab3.txt'
# rm 'full_database.xml'

# %%
# !echo "BIOGRID-ALL-*" >> .gitignore
# !echo "*.xml" >> .gitignore
# !echo ".ipynb_checkpoints/" >> .gitignore

# %%
# !git add .gitignore
# !git commit -m "archivos pesados del repo"
# Out:
# [main 135edd7] archivos pesados del repo
#  3 files changed, 3 insertions(+)
#  create mode 100644 .gitignore
#  delete mode 100644 BIOGRID-ALL-5.0.254.tab3.txt
#  delete mode 100644 full_database.xml

# %%
# !git reset --soft HEAD~1
# !git add .
# !git commit -m "limpieza de datos pesados"
# Out:
# ...
# [main 75bae77] limpieza de datos pesados
#  3 files changed, 252 insertions(+), 6 deletions(-)
#  create mode 100644 .gitignore
#  delete mode 100644 full_database.xml

# %%
# !git push origin main --force
# Out:
# remote: error: Trace: 717e8f579d6b8a7e8c45ed145420bc911b4184e0beee7ecc3990d673905a160c
# remote: error: See https://gh.io/lfs for more information.
# remote: error: File BIOGRID-ALL-5.0.254.tab3.txt is 1444.54 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: File full_database.xml is 1810.17 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano
#  ! [remote rejected] main -> main (pre-receive hook declined)
# error: failed to push some refs to 'https://github.com/fariss2/TFM--Identificacion-de-farmacos-mediante-el-analisis-de-proximidad-en-el-interactoma-humano'

# %%
# !rmdir /s /q .git

# %%
# !git init
# !git branch -M main
# Out:
# Initialized empty Git repository in C:/Users/Nisrin Fariss Lamine/Downloads/tfm/.git/

# %%
# %%writefile .gitignore
# BIOGRID-ALL-*
# *.xml
# .ipynb_checkpoints/
# Out:
# Overwriting .gitignore

# %%
# !git add .
# !git commit -m "repo limpio sin archivos pesados"
# Out:
# ...
# [main (root-commit) df95814] repo limpio sin archivos pesados
#  7 files changed, 11730 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 README.md
#  create mode 100644 TFM.ipynb
#  create mode 100644 Untitled.ipynb
#  create mode 100644 app.py
#  create mode 100644 drugbank_targets_clean.csv
#  create mode 100644 no visualizar datos.txt
